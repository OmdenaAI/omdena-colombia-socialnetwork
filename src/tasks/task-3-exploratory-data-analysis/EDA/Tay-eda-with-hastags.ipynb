# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud, STOPWORDS

# %%
directory ="/Users/huiwen/Documents/Side Projects/Omdena/omdena-colombia-socialnetwork/Untitled/src/data/task-2-preprocessing/merged_data/Merged_twitter_en_topic_modelling.csv"
# directory = "Merged_twitter_en_topic_modelling.csv"
tweet = pd.read_csv(directory)
tweet.head()
# Out:
#    Unnamed: 0                 created_at        id_str  conversation_id_str  \
# 0           0  2021-04-23T07:14:36+00:00  1.385492e+18         1.385492e+18
# 1           1  2021-04-22T04:12:43+00:00  1.385084e+18         1.384885e+18
# 2           2  2021-04-22T04:12:00+00:00  1.385084e+18         1.384803e+18
# 3           3  2021-04-22T04:09:48+00:00  1.385083e+18         1.384882e+18
# 4           4  2021-04-22T03:32:26+00:00  1.385074e+18         1.384941e+18
#
#                                            full_text lang  favorited  \
# 0  📢Join the seminar aiming at supporting #1May #...   en      False
# 1  @julioacosta1701 @DiazCanelB @AlejandroGilF @r...   es      False
# 2  @julioacosta1701 @AliRubioGlez @Vicente7397772...   es      False
# 3  @AdrinMartnezGo1 @julioacosta1701 @DiazCanelB ...   es      False
# 4  @VilmaPrez14 @Laura53538740 @Granma_Digital @D...   es      False
#
#    retweeted  retweet_count  favorite_count  ...  in_reply_to_user_id_str  \
# 0      False              5               4  ...                      NaN
# 1      False              7               1  ...             1.194288e+18
# 2      False              7               1  ...             1.194288e+18
# 3      False              6               0  ...             1.136331e+18
# 4      False              5               1  ...             1.101197e+18
#
#                                             hashtags  \
# 0                          #1May , #1maggio , #1Mayo
# 1  #PrevenirPorLaVida , #PatriaOMuerte , #UnBlock...
# 2  #PrevenirPorLaVida , #PatriaOMuerte , #UnBlock...
# 3  #PrevenirPorLaVida , #PatriaOMuerte , #UnBlock...
# 4  #PrevenirPorLaVida , #PatriaOMuerte , #UnBlock...
#
#                                             mentions  urls  \
# 0  LeftHeinz , Yolanda_Diaz_ , VisentiniLuca , lu...   NaN
# 1  julioacosta1701 , DiazCanelB , AlejandroGilF ,...   NaN
# 2  julioacosta1701 , AliRubioGlez , Vicente739777...   NaN
# 3  AdrinMartnezGo1 , julioacosta1701 , DiazCanelB...   NaN
# 4  VilmaPrez14 , Laura53538740 , Granma_Digital ,...   NaN
#
#                                                media  preprocessed_created_at  \
# 0  [{"url": "https://pbs.twimg.com/media/EzpAFBfX...               2021-04-23
# 1                                                 []               2021-04-22
# 2                                                 []               2021-04-22
# 3                                                 []               2021-04-22
# 4                                                 []               2021-04-22
#
#                                    preprocessed_data emoji_list  \
# 0  ['join', 'seminar', 'aim', 'support', 'may', '...      ['📢']
# 1  ['caliente', 'tweetazo', 'prevenirporlavida', ...         []
# 2  ['sumo', 'prevenirporlavida', 'patriaomuerte',...         []
# 3  ['hay', 'diocancancan', 'prevenirporlavida', '...   ['😅😂🤣🤣']
# 4  ['con', 'mucha', 'conciencia', 'prevenirporlav...         []
#
#    emoticon_list                     data_source
# 0             []  Mayo_ENGLISH_tweets_stweet.csv
# 1             []  Mayo_ENGLISH_tweets_stweet.csv
# 2             []  Mayo_ENGLISH_tweets_stweet.csv
# 3             []  Mayo_ENGLISH_tweets_stweet.csv
# 4             []  Mayo_ENGLISH_tweets_stweet.csv
#
# [5 rows x 30 columns]

# %% [markdown]
# ## 1. Top Words

# %%
plt.figure(figsize = (14,7))
words = tweet[tweet["preprocessed_data"] != ""]
words = [word for xIndex, x in words.iterrows() for word in x["preprocessed_data"].split()]
# print(words)
counter = Counter(words)
x,y = list(map(list,zip(*counter.most_common(7))))
sns.barplot(x = y,y = x)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2. n-gram

# %%
# processed list of words to str
tweet['preprocessed_str'] = tweet['preprocessed_data'].apply(eval).apply(' '.join)
tweet.head()
# Out:
#    Unnamed: 0                 created_at        id_str  conversation_id_str  \
# 0           0  2021-04-23T07:14:36+00:00  1.385492e+18         1.385492e+18
# 1           1  2021-04-22T04:12:43+00:00  1.385084e+18         1.384885e+18
# 2           2  2021-04-22T04:12:00+00:00  1.385084e+18         1.384803e+18
# 3           3  2021-04-22T04:09:48+00:00  1.385083e+18         1.384882e+18
# 4           4  2021-04-22T03:32:26+00:00  1.385074e+18         1.384941e+18
#
#                                            full_text lang  favorited  \
# 0  📢Join the seminar aiming at supporting #1May #...   en      False
# 1  @julioacosta1701 @DiazCanelB @AlejandroGilF @r...   es      False
# 2  @julioacosta1701 @AliRubioGlez @Vicente7397772...   es      False
# 3  @AdrinMartnezGo1 @julioacosta1701 @DiazCanelB ...   es      False
# 4  @VilmaPrez14 @Laura53538740 @Granma_Digital @D...   es      False
#
#    retweeted  retweet_count  favorite_count  ...  \
# 0      False              5               4  ...
# 1      False              7               1  ...
# 2      False              7               1  ...
# 3      False              6               0  ...
# 4      False              5               1  ...
#
#                                             hashtags  \
# 0                          #1May , #1maggio , #1Mayo
# 1  #PrevenirPorLaVida , #PatriaOMuerte , #UnBlock...
# 2  #PrevenirPorLaVida , #PatriaOMuerte , #UnBlock...
# 3  #PrevenirPorLaVida , #PatriaOMuerte , #UnBlock...
# 4  #PrevenirPorLaVida , #PatriaOMuerte , #UnBlock...
#
#                                             mentions  urls  \
# 0  LeftHeinz , Yolanda_Diaz_ , VisentiniLuca , lu...   NaN
# 1  julioacosta1701 , DiazCanelB , AlejandroGilF ,...   NaN
# 2  julioacosta1701 , AliRubioGlez , Vicente739777...   NaN
# 3  AdrinMartnezGo1 , julioacosta1701 , DiazCanelB...   NaN
# 4  VilmaPrez14 , Laura53538740 , Granma_Digital ,...   NaN
#
#                                                media  preprocessed_created_at  \
# 0  [{"url": "https://pbs.twimg.com/media/EzpAFBfX...               2021-04-23
# 1                                                 []               2021-04-22
# 2                                                 []               2021-04-22
# 3                                                 []               2021-04-22
# 4                                                 []               2021-04-22
#
#                                    preprocessed_data emoji_list emoticon_list  \
# 0  ['join', 'seminar', 'aim', 'support', 'may', '...      ['📢']            []
# 1  ['caliente', 'tweetazo', 'prevenirporlavida', ...         []            []
# 2  ['sumo', 'prevenirporlavida', 'patriaomuerte',...         []            []
# 3  ['hay', 'diocancancan', 'prevenirporlavida', '...   ['😅😂🤣🤣']            []
# 4  ['con', 'mucha', 'conciencia', 'prevenirporlav...         []            []
#
#                       data_source  \
# 0  Mayo_ENGLISH_tweets_stweet.csv
# 1  Mayo_ENGLISH_tweets_stweet.csv
# 2  Mayo_ENGLISH_tweets_stweet.csv
# 3  Mayo_ENGLISH_tweets_stweet.csv
# 4  Mayo_ENGLISH_tweets_stweet.csv
#
#                                     preprocessed_str
# 0  join seminar aim support may maggio mayo trade...
# 1  caliente tweetazo prevenirporlavida patriaomue...
# 2  sumo prevenirporlavida patriaomuerte unblockcu...
# 3  hay diocancancan prevenirporlavida patriaomuer...
# 4  con mucha conciencia prevenirporlavida patriao...
#
# [5 rows x 31 columns]

# %%
def get_top_ngram(corpus, n = None):
    vec = CountVectorizer(ngram_range = (n, n)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis = 0) 
    words_freq = [(word, sum_words[0, idx]) 
                  for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)
    return words_freq[:10]


fig, axs = plt.subplots(ncols = 4, figsize = (30, 8))
top_n_bigrams = get_top_ngram(tweet["preprocessed_str"], 1)
x,y = map(list, zip(*top_n_bigrams)) 
sns.barplot(x = y, y = x, ax = axs[0])
top_n_bigrams = get_top_ngram(tweet["preprocessed_str"], 2)
x,y = map(list, zip(*top_n_bigrams)) 
sns.barplot(x = y, y = x, ax = axs[1])
top_tri_grams=get_top_ngram(tweet["preprocessed_str"], n = 3)
x,y = map(list, zip(*top_tri_grams))
sns.barplot(x = y, y = x, ax = axs[2])
top_quad_grams=get_top_ngram(tweet["preprocessed_str"], n = 4)
x,y = map(list, zip(*top_quad_grams))
sns.barplot(x = y, y = x, ax = axs[3])

axs[0].set_title("n = 1")
axs[1].set_title("n = 2")
axs[2].set_title("n = 3")
axs[3].set_title("n = 4")
fig.tight_layout(pad = 1.3)
# fig.savefig("ngram.png")

# %% [markdown]
# ## 3. Word Cloud

# %%
text = tweet.preprocessed_str.values
STOPWORDS = ["amp", "mayo","gazaunderattack'","palestinianlivesmatter",
             "israelterrorist""israelterrorists","save_sheikh_jarrah"]

wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (30, 20),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
